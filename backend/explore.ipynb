# %%
import pandas as pd

# Specify the path to your CSV file
file_path = "PERM_data/PERM_Disclosure_Data_FY2023_Q4.xlsx"
# file_path = "/home/henli/avacacode/f1hub/PERM_Disclosure_Data_FY2023_Q4.csv"


df = pd.read_excel(file_path)

# Read the CSV file into a DataFrame
# df = pd.read_csv(file_path)


# Display the first few rows of the DataFrame
print(df.head())

df.desc
# Out:
#      CASE_NUMBER        CASE_STATUS RECEIVED_DATE DECISION_DATE REFILE  \
# 0  A-22262-24149          Withdrawn    2022-10-02    2022-10-02      N
# 1  A-21187-12839  Certified-Expired    2022-02-03    2022-10-03      N
# 2  A-21327-77110             Denied    2021-11-30    2022-10-03      N
# 3  A-21342-83195  Certified-Expired    2022-02-03    2022-10-03      N
# 4  A-21349-86725  Certified-Expired    2022-02-03    2022-10-03      N
#
#   ORIG_FILE_DATE PREVIOUS_SWA_CASE_NUMBER_STATE SCHD_A_SHEEPHERDER  \
# 0            NaT                            NaN                  N
# 1            NaT                            NaN                  N
# 2            NaT                            NaN                  N
# 3            NaT                            NaN                  N
# 4            NaT                            NaN                  N
#
#                 EMPLOYER_NAME       EMPLOYER_ADDRESS_1  ...  \
# 0     Westgate Shellworld Inc      7012 Muncipal Drive  ...
# ...

# %%
df["EMPLOYER_NAME"].nunique()
# Out:
# 23836

# %%
df["AGENT_ATTORNEY_FIRM_NAME"].nunique()
# Out:
# 5077

# %%
df["AGENT_ATTORNEY_NAME"].nunique()
# Out:
# 6836

# %%
df.groupby("CLASS_OF_ADMISSION").nunique().sort_values(["CASE_NUMBER"])
# Out:
#                     CASE_NUMBER  CASE_STATUS  RECEIVED_DATE  DECISION_DATE  \
# CLASS_OF_ADMISSION
# A-3                           1            1              1              1
# V-1                           1            1              1              1
# T-3                           1            1              1              1
# T-2                           1            1              1              1
# C-2                           1            1              1              1
# T-1                           1            1              1              1
# K-2                           1            1              1              1
# P-2                           1            1              1              1
# C-3                           2            2              2              2
# K-1                           3            2              2              3
# P-4                           3            2              3              3
# ...

# %%
cols2keep = [
"CASE_NUMBER",
"CASE_STATUS",
"RECEIVED_DATE",
"DECISION_DATE",
"EMPLOYER_NAME",
"AGENT_ATTORNEY_FIRM_NAME",
"AGENT_ATTORNEY_NAME", 
"PW_TRACK_NUMBER",
"PW_SOC_TITLE",
"PW_SKILL_LEVEL",
"PW_WAGE",
"PW_SOC_CODE",
"PW_UNIT_OF_PAY",
"PW_WAGE_SOURCE",
"PW_SOURCE_NAME_OTHER",
"PW_DETERMINATION_DATE",
"PW_EXPIRATION_DATE",
"WAGE_OFFER_FROM",
"WAGE_OFFER_TO",
"WAGE_OFFER_UNIT_OF_PAY",
"JOB_TITLE",
"MINIMUM_EDUCATION",
"JOB_EDUCATION_MIN_OTHER",
"MAJOR_FIELD_OF_STUDY",
"REQUIRED_TRAINING",
"REQUIRED_TRAINING_MONTHS",
"REQUIRED_FIELD_OF_TRAINING",
"REQUIRED_EXPERIENCE",
"REQUIRED_EXPERIENCE_MONTHS",
"COUNTRY_OF_CITIZENSHIP",
"CLASS_OF_ADMISSION",
"FOREIGN_WORKER_EDUCATION",
"FOREIGN_WORKER_EDUCATION_OTHER",
"FOREIGN_WORKER_INFO_MAJOR",
"FOREIGN_WORKER_INST_OF_ED",
"FOREIGN_WORKER_ED_INST_COUNTRY"]

# %%
filtereddf = df[cols2keep]
# Out:
#           CASE_NUMBER        CASE_STATUS RECEIVED_DATE DECISION_DATE  \
# 0       A-22262-24149          Withdrawn    2022-10-02    2022-10-02
# 1       A-21187-12839  Certified-Expired    2022-02-03    2022-10-03
# 2       A-21327-77110             Denied    2021-11-30    2022-10-03
# 3       A-21342-83195  Certified-Expired    2022-02-03    2022-10-03
# 4       A-21349-86725  Certified-Expired    2022-02-03    2022-10-03
# ...               ...                ...           ...           ...
# 116422  A-23144-46945          Withdrawn    2023-05-24    2023-09-29
# 116423  A-23144-46992          Withdrawn    2023-05-24    2023-09-29
# 116424  A-23144-46995          Withdrawn    2023-05-24    2023-09-29
# 116425  A-23144-46997          Withdrawn    2023-05-24    2023-09-29
# 116426  A-23144-46999          Withdrawn    2023-05-24    2023-09-29
#
#                      EMPLOYER_NAME  \
# 0          Westgate Shellworld Inc
# 1                       NIKE, INC.
# ...

# %%
filtereddf = df[cols2keep]

# %%
import sqlite3

# %%
conn = sqlite3.connect("perm.db")

# %%
filtereddf.to_sql("y2023", conn, if_exists="replace", index=False) 
conn.close()

# %%
filtereddf.describe()
# Out:
#                        RECEIVED_DATE                  DECISION_DATE  \
# count                         116427                         116427
# mean   2022-06-09 05:54:18.821407232  2023-04-06 15:09:07.759540480
# min              2007-11-20 00:00:00            2022-10-02 00:00:00
# 25%              2022-03-29 00:00:00            2023-01-10 00:00:00
# 50%              2022-06-21 00:00:00            2023-04-06 00:00:00
# 75%              2022-09-01 00:00:00            2023-07-05 00:00:00
# max              2023-05-31 00:00:00            2023-09-29 00:00:00
# std                              NaN                            NaN
#
#             PW_WAGE          PW_DETERMINATION_DATE  \
# count  1.164060e+05                         116357
# mean   9.049774e+04  2022-01-04 21:37:01.408252160
# min    7.250000e+00            2000-07-09 00:00:00
# 25%    5.393400e+04            2021-10-07 00:00:00
# 50%    9.555500e+04            2022-01-11 00:00:00
# ...
